# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
from selenium import webdriver

# %%
import os
os.chdir("D:\\ankit gupta\\New folder\\amazon.inbranded data\\hindware")

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome("D:\\ankit gupta\\chromedriver")

# %%
driver.find_element_by_xpaty('/html/body/div[1]/main/section[2]/div/div[2]/div[2]/div/table/tbody/tr[1]
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-20-a805e26245e3> in <module>
# ----> 1 driver.find_element_by_xpath('/html/body/div[1]/main/section[2]/div/div[2]/div[2]/div/table/tbody/tr[1]').click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ...

# %%
yay='/html/body/div[1]/section/div/div/div/div/div/section/div/div/div/div[4]/div[6]/div[2]/div/div[2]/div[2]/div[7]/div/table/tbody/tr[{}]/td[1]/table[1]/tbody/tr[1]/td'
data=[]
for i in range(1,27):
    ank=yay.format(i)
    try:
        result=driver.find_element_by_xpath(ank).text
        data.append(result)
    except:
        pass

# %%
data
# Out:
# ['Himgiri Automobiles-Noida.',
#  'Himgiri Automobiles-Sahibabad.',
#  'CSG Automobiles',
#  'RM-Kotputli',
#  'Sumer Sons - Agra',
#  'GAML-Tinsukia',
#  'Sumer Sons - Etawah',
#  'RM-Ramchandrapura',
#  'GAML-Tezpur',
#  'Indian Auto Wheels',
#  'Sandeep Trucks Pvt Ltd-Nasirabad',
#  'Future Trucks-Kanpur',
#  'GAML-Barpeta',
#  'GAML-Guwahati_New',
#  'Satyam Solutions-Gwalior',
#  'D.R.Brijmohan & Sons Pvt Ltd',
#  'Shivang Automobiles-Bhojpur',
#  'DCS Motors Pvt Ltd-Purnea',
#  'GAML-Varanasi',
#  'Satyam Solutions-Shivpuri',
#  'DCS Motors Pvt Ltd-Begusarai',
#  'Nataraj Mobiles- Jhansi',
#  'Sandeep Trucks Pvt Ltd-Chanderiya',
#  'Sona Wheels-Malda',
#  'Lamjingba Motors Pvt. Ltd',
#  'Jagannath Vahan Pvt Ltd',
#  'TVS-Neemuch',
#  'Navneet Motors-Udaipur',
#  'Anil Motors-Katni',
#  'Shree Automotive-Birbhum',
#  'Pooja Marketing-Palanpur',
#  'Shree Automotive-Durgapur',
#  'AMPL-Himmatnagar',
#  'Shree Automotive-Asansol',
#  'Himatsingka Next LLP.',
# ...

# %%
driver.get("https://ebuild.in/brand-dealers?category=bath&brand=hindware")

# %%
driver.find_element_by_xpath('/html/body/form/div[2]/div[2]/div/div/div/div[1]/div[2]/div/section/div/div[2]/div[4]').text
# Out:
# 'Vijeta Electronics\nShiv Mandir Lane, Sakchi, Jamshedpur, Jharkhand, India\n 06434 222434\n(+1 more address)'

# %%
com="https://ebuild.in/vitra-eczacibasi-group-retailers?page={}"
yaya="/html/body/form/div[2]/div[2]/div/div/div/div[1]/div[2]/div/section/div/div[2]/div[{}]"

data=[]
for i in range (1,3):
    ank2=com.format(i)
    driver.get(ank2)
    for i in range(2,200):
        ank=yaya.format(i)
        try:
            result=driver.find_element_by_xpath(ank).text
            data.append(result)
        except:
            pass

# %%
len(data)
# Out:
# 52

# %%
data=pd.DataFrame(data,columns=["rawdata"])

# %%
data=data["rawdata"].str.split(pat='\n',n=3,expand=True)

# %%
data
# Out:
#                                   0  \
# 0                       Abc Emporio
# 1                     Abc Kanhangad
# 2             Abc Sales Corporation
# 3                   Amf Home Centre
# 4                       Amrut & Co.
# 5                    Amset Ambience
# 6      Asiatic Construction Company
# 7                      B.P.Agarawal
# 8                        Baba Tiles
# 9                  Bath Magic World
# 10                     Bath N Style
# 11               Ceramica Exclusive
# 12                Ddr International
# 13                    Decoreta Plus
# 14                      Elite Space
# 15                         Gh Karia
# 16                   Hhys Inframart
# 17                          Impulse
# 18    Indian Marble & Granite Store
# 19                         Interdec
# 20                    J B Homestore
# 21                      Jain Marble
# 22                   Karishma Tiles
# 23               Kasana Enterprises
# 24                Khendwal Brothers
# ...

# %%
data.to_excel('vitra.xlsx')
