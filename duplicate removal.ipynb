# %%
import pandas as pd

# %%
import numpy as np

# %%
import os
from selenium.webdriver.support.ui import Select

# %%
os.chdir("C:\\Users\\admin\\Desktop\\New folder\\brand data\\nikon")

# %%
data=pd.read_excel("nikon.xlsx")

# %%
data
# Out:
#       Unnamed: 0                                            0  \
# 0            0.0                               Amico Brothers
# 1            1.0         Gowri Camera World (Experience Zone)
# 2            2.0  Krishna Digital Color Lab (Experience Zone)
# 3            3.0   Shiva Jyothi Electronics (Experience Zone)
# 4            4.0                                   Cell World
# ...          ...                                          ...
# 1146         NaN        Spectrum Color Labs (Experience Zone)
# 1147         NaN                         Abhinaba Electronics
# 1148         NaN                            Dizi Max Infotech
# 1149         NaN          Great Eastern Trading Co (Sodepore)
# 1150         NaN                 Khosla Electronics (Sodepur)
#
#                                                       1  \
# 0     Near Pmc Bus Stop, Old Mumbai Pune Road, 41103...
# 1     47-10-3, G6, Medicherla Towers, Opp. Fortune S...
# ...

# %%
df = data.drop_duplicates([2], keep='first')

# %%
df
# Out:
#       Unnamed: 0                                            0  \
# 0            0.0                               Amico Brothers
# 1            1.0         Gowri Camera World (Experience Zone)
# 2            2.0  Krishna Digital Color Lab (Experience Zone)
# 3            3.0   Shiva Jyothi Electronics (Experience Zone)
# 4            4.0                                   Cell World
# ...          ...                                          ...
# 1145         NaN        Great Eastern Trading Co. (Serampore)
# 1147         NaN                         Abhinaba Electronics
# 1148         NaN                            Dizi Max Infotech
# 1149         NaN          Great Eastern Trading Co (Sodepore)
# 1150         NaN                 Khosla Electronics (Sodepur)
#
#                                                       1  \
# 0     Near Pmc Bus Stop, Old Mumbai Pune Road, 41103...
# 1     47-10-3, G6, Medicherla Towers, Opp. Fortune S...
# ...

# %%
df.to_excel("nikon.xlsx")
