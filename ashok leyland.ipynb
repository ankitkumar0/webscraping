# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
from selenium import webdriver

# %%
import os
os.chdir('D:\\ankit gupta\\New folder\\amazon.inbranded data\\ashok laylend')

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome("D:\\ankit gupta\\chromedriver")

# %%
driver.get('https://www.ashokleyland.com/en/dealer-locator')

# %%
yaya = '/html/body/div[1]/section/div/div/div/div/div/section/div/div/div/div[4]/div[6]/div[2]/div/div[2]/div[2]/div[7]/div/table/tbody/tr[{0}]/td[{1}]/table[1]/tbody'

data = []
for i in range(1,148):
    u = 1
    ank=yaya.format(i,u)
    v = 2
    vis=yaya.format(i,v)
    try:
        for i in [ank,vis]:
            result=driver.find_element_by_xpath(i).text
            data.append(result)
    except:
        pass

# %%
data
# Out:
# ['Anwar Motors\n262 G/2, Madurai Road, Selva Vignesh Nagar, Tharapuram,627358\n6384441255\ncm@anwarmotors.com\nSAC code: 77088\nSales,Service,Spares',
#  'Anwar Motors\n2/418, Ponnagaram, Palayamkottai Main Road, OPP Govt. ITI, Korampallam628101\n6384441315\namservicetuticorin@gmail.com\nSAC code: 79013\nService,Spares',
#  'Amman Auto Pvt. Ltd.\nNo, 519 & 522 AVINASHI HIGHWAY ROAD, SULUR PIRIVU, OPP BMW SHOWROOM, Neelambur641407\n9047010435\narun@ammanuto.com , sales@ammanauto.com\nSAC code: 20384\nSales,Service,Spares',
#  'Amman Auto Pvt. Ltd.\nR.S. No. 305/2,  Veerapan Chatram Panchayat, Perundurai Road 638009\n9047047583\nerdsales@ammanauto.com\nSAC code: 29956\nSales,Service,Spares',
#  'Amman Auto Pvt. Ltd.\nNo:17,Oyyangadu Thottam,Lakshminagar, Bhavani638317\n9047047583\nerdsales@ammanauto.com\nSAC code: 39734\nService,Spares',
#  'Amman Auto Pvt. Ltd.\nShed No 28,Sidco Industrial Estate,Kuruchi641021\n9047010435\nsidcoservice@ammamauto.com\nSAC code: 83317\nService,Spares',
# ...

# %%
data=pd.DataFrame(data,columns=['rawdata'])

# %%
datap=data['rawdata'].str.split(pat='\n',n=3,expand=True)

# %%
datap.to_excel("ashokspare.xlsx")
